# %% [markdown]
# # Jupyter

# %% [markdown]
# Jupyter представляет собой веб-интерфейс для исполнения кода в тетрадях \ ноубуках (notebook).
# Тетрадь делится на ячейки двух видов: ячейки с текстом (Markdown) и ячейки с кодом.
#
#
# Конкретно эта ячейка — Markdown, в ней можно писать текст, в том числе страшные формулы ($\LaTeX$):
#
# $$\frac{\partial g}{\partial X} = \frac{\partial f}{\partial X} + \left(\frac{\partial f}{\partial X}\right)^T -
# \mathrm{diag}\left(\frac{\partial f}{\partial x_{11}}, \frac{\partial f}{\partial x_{22}},\ldots,
# \frac{\partial f}{\partial x_{nn}}\right)$$
#
# Можно вставлять <strike>мемы</strike> картинки:
#
# <img src='https://pp.userapi.com/c637227/v637227487/5d6d2/spUnGgKfQdA.jpg' width="500" />
#
# Можно вставлять сниппеты с кодом (без возможности выполнить):
#
# ```python
# import antigravity
# ```
#
# Другой вид ячеек: ячейки с кодом. Каждую ячейку можно выполнять по отдельности. Во время выполнения ячейки под ней пишется весь вывод на стандартный поток (все `print`); после выполнения — результат (значение, которое возвращается последним выражением).

# %% [markdown]
# Есть два режима работы с ячейками - **режим правки (ввода)** и **командный режим**. Если вы находитесь в режиме правки, в правом верхнем углу вы увидите нарисованный карандаш.
# В режиме правки вы можете редактировать содержимое ячейки.
# В командном режиме вы можете выполнять команды (часть из них ниже)

# %% [markdown]
# Важные сочетания клавиш:
# * Tab: автодополнение
# * Shift+Tab: подсказка; Shift+Tab, держа Shift нажать Tab еще раз: закрепленная подсказка
# * Ctrl+S: сохранить ноутбук
# * Esc: выход из режима ввода текста в ячейку, после этого при помощи стрелок можно выбрать другую ячейку
# * Shift+Enter: выполнение текущей ячейки + переключение фокуса на следующую существующую
# * Alt+Enter: выполнение текущей ячейки + создание новой чистой ячейки снизу + переключение фокуса на нее
# * Ctrl+Enter: выполнение текущей ячейки, фокус остается на ней же
#
# Еще немного важных сочетаний:
#  * a: создать пустую ячейку **над** текущей ячейкой (от above)
#  * b: создать пустую ячейку **под** текущей ячейкой (от below)
#  * dd: удалить текущую ячейку (нужно нажать d два раза)
#  * z: отменить удаление ячейки
#  * o: скрыть вывод текущей ячейки
#  * m: превратить ячейку в ячейку с текстом (Markdown)
#  * y: превратить ячейку в ячейку с кодом
#
# Другие команды доступны по Esc+H.
#
# Jupyter поддерживает и другие языки, их поддержку можно добавить с помощью добавления соответствующих kernels.

# %%
# Блок с кодом на Python
print("Hello Jupyter!")
print("Another line: {}".format(2 + 2))
"This string is lost — it is not in the end."
"This string is the result of the cell."
# Out:
# Hello Jupyter!
# Another line: 4
# 'This string is the result of the cell.'

# %%
def s():
    return 1, 2, 3, 4

# %%
s()
# Out:
# (1, 2, 3, 4)

# %%
a = """
dfdf
adfdaf
asdf
"""

# %% [markdown]
# Помимо кода, в блоке могут быть специфические для Jupyter вещи:
# * `%magic` команды — дополнительное поведение, например можно замерить время выполнения ячейки

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Один символ `%` означает, что применяем команду только к текущей строке.

# %%
# %timeit plt.pause(1)
# Out:
# 1 s ± 42.6 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Два символа `%` означают, что применяем команду ко всей ячейке.

# %%
# %%timeit

for _ in range(300):
    for _ in range(300):
        2 + 3 + 5 + 7
# Out:
# 1.73 ms ± 169 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ---

# %% [markdown]
# * `!system` команды — вызовы к программам из командной строки

# %% [markdown]
# bang

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 920D-D51A
#
#  Directory of C:\Users\Porhalo\1Skill
#
# 26.01.2021  12:58    <DIR>          .
# 26.01.2021  12:58    <DIR>          ..
# 24.01.2021  15:28    <DIR>          .ipynb_checkpoints
# 07.10.2019  12:37    <DIR>          111
# 07.10.2019  16:17             2я984 111.csv
# 12.10.2019  11:40             3я551 111.xls
# 07.10.2019  15:25             4я015 112
# 07.10.2019  15:39             4я015 112.xls
# 19.01.2020  15:21    <DIR>          1All_skill
# 11.10.2019  20:39             2я984 clf.xls
# 14.05.2020  16:57           661я909 ClusteringAlgorithms(2).ipynb
# 13.01.2020  16:26    <DIR>          Data
# 07.10.2019  15:39            17я920 Dataframe.xls
# 12.10.2019  12:17           150я016 Dataframe_first.xls
# 07.10.2019  23:53           150я016 Dataframe_null.xls
# 12.10.2019  18:17           467я936 hakaton.ipynb
# 07.10.2019  13:01            11я992 hakaton0.ipynb
# 26.01.2021  12:58           380я653 m1_part1_Jupyter_tutorial(1).ipynb
# 24.01.2021  16:12            15я678 m1_part2_ds_example(1).ipynb
# 26.01.2021  11:46            13я990 m1_part2_ds_example.ipynb
# 13.01.2020  13:10            21я346 m2_part1_nans(3).ipynb
# 05.03.2020  16:41            21я364 m2_part1_nans.ipynb
# 05.03.2020  17:04            18я426 m2_part2_normalization(1).ipynb
# 05.03.2020  15:04            62я977 m2_part3_visualization.ipynb
# 09.04.2020  17:23            46я682 m2_part4_feature_engineering.ipynb
# 20.01.2020  11:59            57я755 m2_part5_outliers.ipynb
# 11.10.2019  16:53         1я348я456 m5.4_Џа ЄвЁЄ .ipynb
# 07.10.2019  12:58         2я137я162 m5.7_Џа ЄвЁЄ .ipynb
# 11.10.2019  20:27           373я450 m6.3_Џа ЄвЁЄ (1).ipynb
# 09.10.2019  17:31           369я416 m6.3_Џа ЄвЁЄ .ipynb
# 10.10.2019  17:17            17я122 m6.5_Џа ЄвЁЄ .ipynb
# 26.01.2020  12:07           130я548 miscellanea.ipynb
# 16.11.2019  16:29             7я513 Series_dataframe.ipynb
# 23.04.2020  16:33            25я065 SF_LR1(2).ipynb
# 23.04.2020  16:58         2я689я622 SF_LR1.ipynb
# 25.01.2020  14:11            15я213 SF_LR2.ipynb
# 07.10.2019  15:33             2я984 submission_sample.csv
# 12.08.2019  14:51             2я698 submission_sample0.csv
# 11.10.2019  17:28            16я631 Tasks5.1.ipynb
# 03.10.2019  23:44            16я374 Tasks5.2.ipynb
# 13.01.2020  14:25        97я391я029 train.csv
# 18.11.2019  23:09             9я165 Untitled.ipynb
# 13.01.2020  13:12                72 Untitled1.ipynb
#               37 File(s)    106я668я729 bytes
#                6 Dir(s)  26я904я006я656 bytes free

# %%
# !curl http://wttr.in/~Moscow
# Out:
# Weather report: Moscow
#
#      \  /       Partly cloudy
#    _ /"".-.     -4..+1 В°C
#      \_(   ).   в†ђ 26 km/h
#      /(___(__)  10 km
#                 0.0 mm
#                                                        в”Њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ђ
# в”Њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¤  Tue 26 Jan в”њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ђ
# в”‚            Morning           в”‚             Noon      в””в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”�     Evening           в”‚             Night            в”‚
# в”њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¤
# в”‚               Overcast       в”‚  _`/"".-.     Light snow     в”‚      .-.      Heavy snow     в”‚  _`/"".-.     Moderate or heвЂ¦в”‚
# в”‚      .--.     -6..0 В°C       в”‚   ,\_(   ).   -6..0 В°C       в”‚     (   ).    -5..+1 В°C      в”‚   ,\_(   ).   -5..0 В°C       в”‚
# в”‚   .-(    ).   в†– 23-34 km/h   в”‚    /(___(__)  в†– 25-37 km/h   в”‚    (___(__)   в†– 22-36 km/h   в”‚    /(___(__)  в†‘ 21-33 km/h   в”‚
# в”‚  (___.__)__)  10 km          в”‚      *  *  *  10 km          в”‚    * * * *    2 km           в”‚     * * * *   4 km           в”‚
# в”‚               0.0 mm | 0%    в”‚     *  *  *   0.0 mm | 0%    в”‚   * * * *     1.1 mm | 0%    в”‚    * * * *    1.1 mm | 0%    в”‚
# в””в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”�
#                                                        в”Њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ђ
# в”Њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¤  Wed 27 Jan в”њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ђ
# в”‚            Morning           в”‚             Noon      в””в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”�     Evening           в”‚             Night            в”‚
# в”њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¤
# в”‚  _`/"".-.     Light snow     в”‚  _`/"".-.     Moderate or heвЂ¦в”‚    \  /       Partly cloudy  в”‚               Mist           в”‚
# в”‚   ,\_(   ).   -7..-1 В°C      в”‚   ,\_(   ).   -6..0 В°C       в”‚  _ /"".-.     -6..-2 В°C      в”‚  _ - _ - _ -  -8..-4 В°C      в”‚
# в”‚    /(___(__)  в†‘ 22-32 km/h   в”‚    /(___(__)  в†‘ 23-32 km/h   в”‚    \_(   ).   в†‘ 13-21 km/h   в”‚   _ - _ - _   в†‘ 10-18 km/h   в”‚
# в”‚      *  *  *  5 km           в”‚     * * * *   9 km           в”‚    /(___(__)  10 km          в”‚  _ - _ - _ -  7 km           в”‚
# в”‚     *  *  *   0.5 mm | 0%    в”‚    * * * *    0.1 mm | 0%    в”‚               0.0 mm | 0%    в”‚               0.0 mm | 0%    в”‚
# в””в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”�
#                                                        в”Њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ђ
# в”Њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¤  Thu 28 Jan в”њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ђ
# в”‚            Morning           в”‚             Noon      в””в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¬в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”�     Evening           в”‚             Night            в”‚
# в”њв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”јв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”¤
# в”‚      .-.      Light freezing в”‚      .-.      Light rain     в”‚      .-.      Moderate or heвЂ¦в”‚      .-.      Light sleet    в”‚
# в”‚     (   ).    -7..-4 В°C      в”‚     (   ).    -6..-1 В°C      в”‚     (   ).    -4..-1 В°C      в”‚     (   ).    -4 В°C          в”‚
# в”‚    (___(__)   в†ђ 10-15 km/h   в”‚    (___(__)   в†ђ 13-20 km/h   в”‚    (___(__)   в†– 17-26 km/h   в”‚    (___(__)   в†– 17-26 km/h   в”‚
# в”‚     вЂ� * вЂ� *   3 km           в”‚     вЂ� вЂ� вЂ� вЂ�   7 km           в”‚     *  *  *   8 km           в”‚     вЂ� * вЂ� *   7 km           в”‚
# в”‚    * вЂ� * вЂ�    0.3 mm | 0%    в”‚    вЂ� вЂ� вЂ� вЂ�    1.0 mm | 0%    в”‚    *  *  *    1.9 mm | 0%    в”‚    * вЂ� * вЂ�    2.3 mm | 0%    в”‚
# в””в”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”ґв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”Ђв”�
# Location: РњРѕСЃРєРІР°, Р¦РµРЅС‚СЂР°Р»СЊРЅС‹Р№ Р°РґРјРёРЅРёСЃС‚СЂР°С‚РёРІРЅС‹Р№ РѕРєСЂСѓРі, РњРѕСЃРєРІР°, Р¦Р¤Рћ, Р Р¤ [55.7506828,37.6174976]
#
# Follow @igor_chubin for wttr.in updates

# %% [markdown]
# ---

# %%
# Красивые графики
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (12.0, 7.0)

matsize = 300
matrix = np.random.exponential(size=(matsize, matsize))
_ = plt.imshow(matrix)
_ = plt.colorbar()
plt.show()
